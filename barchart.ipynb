# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style='white')

# %%
sns.set(style='white')
vals = ['WebKB',2,92,'WebKB',3,92,'WebKB',4,89]
vals += ['Yelp',2,85,'Yelp',3,88,'Yelp',4,89]
vals += ['Segmentation',2,96,'Segmentation',3,96,'Segmentation',4,97]
vals += ['Movielens',2,86,'Movielens',3,87,'Movielens',4,87]
vals = np.array(vals)
vals = vals.reshape(12,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': int,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df,size=4, aspect=1.5,
                 kind="bar", palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=3)
g.savefig("figs/conv.pdf")
# Out:
# ds         object
# conv        int32
# ROC-AUC     int32
# dtype: object
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vals = ['WebKB',2,92,'WebKB',3,92,'WebKB',4,91,'WebKB',5,91]
vals += ['Yelp',2,88,'Yelp',3,89,'Yelp',4,88,'Yelp',5,88]
vals += ['Segmentation',2,97,'Segmentation',3,97,'Segmentation',4,97,'Segmentation',5,96]
vals += ['Movielens',2,87,'Movielens',3,87,'Movielens',4,86,'Movielens',5,86]
vals = np.array(vals)
vals = vals.reshape(16,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': int,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.6, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4)
g.savefig("figs/ks.pdf")
# Out:
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vals = ['WebKB','sigmoid',91,'WebKB','relu',91,'WebKB','linear',92,'WebKB','tanh',90]
vals += ['Yelp','sigmoid',88,'Yelp','relu',88,'Yelp','linear',88,'Yelp','tanh',84]
vals += ['Segmentation','sigmoid',97,'Segmentation','relu',97,'Segmentation','linear',97,'Segmentation','tanh',96]
vals += ['Movielens','sigmoid',87,'Movielens','relu',87,'Movielens','linear',87,'Movielens','tanh',87]
vals = np.array(vals)
vals = vals.reshape(16,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': str,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.6, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4)
g.savefig("figs/activation.pdf")
# Out:
# ds         object
# conv       object
# ROC-AUC     int32
# dtype: object
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vals = ['WebKB','20%',92,'WebKB','50%',92,'WebKB','70%',89,'WebKB','80%',81]
vals += ['Yelp','20%',86,'Yelp','50%',87,'Yelp','70%',85,'Yelp','80%',74]
vals += ['Segmentation','20%',97,'Segmentation','50%',96,'Segmentation','70%',95,'Segmentation','80%',92]
vals += ['Movielens','20%',86,'Movielens','50%',87,'Movielens','70%',86,'Movielens','80%',80]
vals = np.array(vals)
vals = vals.reshape(16,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': str,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.5, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4)
g.savefig("figs/dropout.pdf")
# Out:
# ds         object
# conv       object
# ROC-AUC     int32
# dtype: object

# %%
vals = ['WebKB',20,92,'WebKB',50,93,'WebKB',100,92,'WebKB',200,92]
vals += ['Yelp',20,73,'Yelp',50,85,'Yelp',100,88,'Yelp',200,88]
vals += ['Segmentation',20,92,'Segmentation',50,97,'Segmentation',100,97,'Segmentation',200,96]
vals += ['Movielens',20,87,'Movielens',50,87,'Movielens',100,86,'Movielens',200,85]
vals = np.array(vals)
vals = vals.reshape(16,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': int,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.5, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4)
g.savefig("figs/epochs.pdf")
# Out:
# ds         object
# conv        int32
# ROC-AUC     int32
# dtype: object
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vals = ['WebKB',2,92,'WebKB',4,90,'WebKB',6,92,'WebKB',8,91]
vals += ['Yelp',2,82,'Yelp',4,85,'Yelp',6,88,'Yelp',8,88]
vals += ['Segmentation',2,92,'Segmentation',4,97,'Segmentation',6,96,'Segmentation',8,96]
vals += ['Movielens',2,87,'Movielens',4,87,'Movielens',6,85,'Movielens',8,86]
vals = np.array(vals)
vals = vals.reshape(16,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': int,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.5, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=4)
g.savefig("figs/channels.pdf")
# Out:
# ds         object
# conv        int32
# ROC-AUC     int32
# dtype: object
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
vals = ['WebKB','with exchangeability',87,'WebKB','without exchangeability',92]
vals += ['Yelp','with exchangeability',86,'Yelp','without exchangeability',88]
vals += ['Segmentation','with exchangeability',97,'Segmentation','without exchangeability',97]
vals += ['Movielens','with exchangeability',86,'Movielens','without exchangeability',87]
vals = np.array(vals)
vals = vals.reshape(8,3)
df = pd.DataFrame(data=vals,columns=['ds','conv','ROC-AUC'])
convert_dict = {'ds': str, 'conv': str,'ROC-AUC':int} 
  
df = df.astype(convert_dict) 
print(df.dtypes)
g = sns.catplot(x="ds", y="ROC-AUC", hue="conv", data=df, kind="bar",size=4, aspect=1.5, palette="muted",legend_out=True)
g.set_xlabels("")
g._legend.remove()
handles = g._legend_data.values()
labels = g._legend_data.keys()
g.fig.legend(handles=handles, labels=labels, loc='upper center', ncol=3)
g.savefig("figs/exchangeability.pdf")
# Out:
# ds         object
# conv       object
# ROC-AUC     int32
# dtype: object
# C:\Users\jotit\Anaconda3\lib\site-packages\seaborn\categorical.py:3692: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
